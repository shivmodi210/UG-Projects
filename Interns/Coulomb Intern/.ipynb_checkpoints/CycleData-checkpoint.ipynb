# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from smart_open import smart_open

aws_key = 'AKIAQOCTCRYHUL2EAI6U'
aws_secret = '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'

bucket_name = 'databricks-parent/public_battery_datasets/batteryarchive.org/SNL-Datasets'
object_key = 'SNL_18650_LFP_15C_0-100_0.5-1C_a_cycle_data.csv'

path = 's3://{}:{}@{}/{}'.format(aws_key, aws_secret, bucket_name, object_key)

df = pd.read_csv(smart_open(path))
df.head()
# Out:
#    Cycle_Index                  Start_Time                    End_Time  \
# 0          1.0  2018-02-01 10:02:10.002962  2018-02-01 14:22:45.311114
# 1          2.0  2018-02-01 14:22:45.342898  2018-02-01 18:40:11.752185
# 2          3.0  2018-02-01 18:40:11.813887  2018-02-01 22:57:06.174243
# 3          4.0  2018-02-01 22:57:06.174411  2018-02-02 05:26:31.589611
# 4          5.0  2018-02-02 05:28:31.613008  2018-02-02 08:34:59.918204
#
#    Test_Time (s)  Min_Current (A)  Max_Current (A)  Min_Voltage (V)  \
# 0      15645.311            -0.55             0.55            1.998
# 1      31091.752            -0.55             0.55            1.995
# 2      46506.174            -0.55             0.55            1.997
# 3      69871.589            -1.10             0.55            1.995
# 4      81179.918            -1.10             0.55            1.993
#
#    Max_Voltage (V)  Charge_Capacity (Ah)  Discharge_Capacity (Ah)  \
# ...

# %%
columns = np.array(df.columns)
index = columns[0]
print(columns)
print(index)
print(df[columns[0]][1])
# Out:
# ['Cycle_Index' 'Start_Time' 'End_Time' 'Test_Time (s)' 'Min_Current (A)'
#  'Max_Current (A)' 'Min_Voltage (V)' 'Max_Voltage (V)'
#  'Charge_Capacity (Ah)' 'Discharge_Capacity (Ah)' 'Charge_Energy (Wh)'
#  'Discharge_Energy (Wh)']
# Cycle_Index
# 2.0

# %%
len(columns)
# Out:
# 12

# %%
for i in range(4,len(columns)):
    plt.figure()
    plt.plot(df.iloc[525:575,0],df.iloc[525:575,i])
    plt.xlabel('Cycle_Index')
    plt.ylabel(columns[i])
    plt.title(columns[i])

# %%
#columns = ['Min_Current (A)', 'Max_Current (A)', 'Min_Voltage (V)',
#       'Max_Voltage (V)', 'Charge_Capacity (Ah)', 'Discharge_Capacity (Ah)',
#       'Charge_Energy (Wh)', 'Discharge_Energy (Wh)']

for i in range(4,len(columns)):
    plt.figure()
    plt.plot(df[index],df[columns[i]])
    plt.xlabel('Cycle_Index')
    plt.ylabel(columns[i])
    plt.title(columns[i])

# %%
for i in range(2,6):
    plt.figure()
    plt.plot(df[index],df[columns[2*i]],df[columns[2*i+1]])
    plt.xlabel('Cycle_Index')
    #plt.ylabel(columns[i])
    plt.title(columns[2*i])
