# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from smart_open import smart_open

aws_key = 'AKIAQOCTCRYHUL2EAI6U'
aws_secret = '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'

bucket_name = 'databricks-parent/public_battery_datasets/batteryarchive.org/SNL-Datasets'
#object_key = 'SNL_18650_LFP_15C_0-100_0.5-1C_a_cycle_data.csv'
object_key = 'SNL_18650_LFP_15C_0-100_0.5-1C_a_timeseries.csv'
path = 's3://{}:{}@{}/{}'.format(aws_key, aws_secret, bucket_name, object_key)

df = pd.read_csv(smart_open(path))
df.head()
df.tail()
# Out:
#                          Date_Time  Test_Time (s)  Cycle_Index  Current (A)  \
# 465880  2020-02-15 18:33:35.088926   4.891440e+07       4551.0          0.0
# 465881  2020-02-15 18:33:36.108916   4.891440e+07       4551.0          0.0
# 465882  2020-02-15 18:33:37.110896   4.891440e+07       4551.0          0.0
# 465883  2020-02-15 18:33:38.130905   4.891440e+07       4551.0          0.0
# 465884  2020-02-15 18:33:38.310884   4.891440e+07       4551.0          0.0
#
#         Voltage (V)  Charge_Capacity (Ah)  Discharge_Capacity (Ah)  \
# 465880        2.648                   0.0                      0.0
# 465881        2.648                   0.0                      0.0
# 465882        2.648                   0.0                      0.0
# 465883        2.648                   0.0                      0.0
# 465884        2.648                   0.0                      0.0
#
#         Charge_Energy (Wh)  Discharge_Energy (Wh)  \
# 465880                 0.0                    0.0
# 465881                 0.0                    0.0
# 465882                 0.0                    0.0
# 465883                 0.0                    0.0
# 465884                 0.0                    0.0
#
#         Environment_Temperature (C)  Cell_Temperature (C)
# 465880                       15.030                15.319
# 465881                       15.030                15.395
# 465882                       15.030                15.395
# 465883                       15.030                15.319
# 465884                       14.984                15.349

# %%
columns = np.array(df.columns)
index = columns[1]
print(len(columns))
print(index)
print(columns[1])
# Out:
# 11
# Test_Time (s)
# Test_Time (s)

# %%
print(df.iloc[0:1422,1])
# Out:
# 0          10.002
# 1          20.016
# 2          30.031
# 3          40.046
# 4          50.061
#           ...
# 1417    15405.450
# 1418    15465.477
# 1419    15525.505
# 1420    15585.532
# 1421    15645.311
# Name: Test_Time (s), Length: 1422, dtype: float64

# %%
for i in range(3, len(columns)):
    plt.figure()
    plt.plot(df.iloc[0:1422,1],df.iloc[0:1422,i])
    plt.xlabel('Test_Time (s)')
    plt.ylabel(columns[i])
    plt.title(columns[i])

# %%
for i in range(3, len(columns)):
    plt.figure()
    plt.plot(df.iloc[464475:465884,1],df.iloc[464475:465884,i])
    plt.xlabel('Test_Time (s)')
    plt.ylabel(columns[i])
    plt.title(columns[i])
