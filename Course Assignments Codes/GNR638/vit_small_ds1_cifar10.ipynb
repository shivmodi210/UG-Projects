# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# # Train a Vision Transformer on small datasets

# %%
# !pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.18.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 15.5 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.18.0

# %%
import math
import numpy as np
import tensorflow as tf
from tensorflow import keras
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
from tensorflow.keras import layers

# Setting seed for reproducibiltiy
SEED = 42
keras.utils.set_random_seed(SEED)

# %% [markdown]
# ## Prepare the data

# %%
NUM_CLASSES = 10
INPUT_SHAPE = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %% [markdown]
# ## Configure the hyperparameters
#
# The hyperparameters are different from the paper. Feel free to tune
# the hyperparameters yourself.

# %%
# DATA
BUFFER_SIZE = 512 # Double of batch size usually
BATCH_SIZE = 256 # 128 in paper

# AUGMENTATION
IMAGE_SIZE = 72 # We'll resize input images to this size
PATCH_SIZE = 6 # Set to 8 in paper, Size of the patches to be extract from the input images
NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

# OPTIMIZER
LEARNING_RATE = 0.001 # 0.003 in paper
WEIGHT_DECAY = 0.0001

# TRAINING
EPOCHS = 50 # Set to 100 in paper

# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8 # Depth was 9 in paper
PROJECTION_DIM = 64 # hidden dimention is 192
NUM_HEADS = 4 # 12 in paper
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2, # Encoder MLP dimension is TRANSFORMER_UNITS
    PROJECTION_DIM,
]
MLP_HEAD_UNITS = [2048, 1024] # Size of last MLP

# %% [markdown]
# ## Use data augmentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %% [markdown]
# ## Implement Shifted Patch Tokenization

# %%
class ShiftedPatchTokenization(layers.Layer):
    def __init__(
        self,
        image_size=IMAGE_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = layers.Reshape((num_patches, -1))
        self.projection = layers.Dense(units=projection_dim)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)

# %% [markdown]
# ### Visualize the patches

# %%
# Get a random image from the training dataset
# and resize the image
image = x_train[np.random.choice(range(x_train.shape[0]))]
resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(IMAGE_SIZE, IMAGE_SIZE)
)

# Vanilla patch maker: This takes an image and divides into
# patches as in the original ViT paper
(token, patch) = ShiftedPatchTokenization(vanilla=True)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
count = 1
plt.figure(figsize=(4, 4))
for row in range(n):
    for col in range(n):
        plt.subplot(n, n, count)
        count = count + 1
        image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 3))
        plt.imshow(image)
        plt.axis("off")
plt.show()

# Shifted Patch Tokenization: This layer takes the image, shifts it
# diagonally and then extracts patches from the concatinated images
(token, patch) = ShiftedPatchTokenization(vanilla=False)(resized_image / 255.0)
(token, patch) = (token[0], patch[0])
n = patch.shape[0]
shifted_images = ["ORIGINAL", "LEFT-UP", "LEFT-DOWN", "RIGHT-UP", "RIGHT-DOWN"]
for index, name in enumerate(shifted_images):
    print(name)
    count = 1
    plt.figure(figsize=(4, 4))
    for row in range(n):
        for col in range(n):
            plt.subplot(n, n, count)
            count = count + 1
            image = tf.reshape(patch[row][col], (PATCH_SIZE, PATCH_SIZE, 5 * 3))
            plt.imshow(image[..., 3 * index : 3 * index + 3])
            plt.axis("off")
    plt.show()
# Out:
# ORIGINAL
# LEFT-UP
# LEFT-DOWN
# RIGHT-UP
# RIGHT-DOWN

# %% [markdown]
# ## Implement the patch encoding layer
#
# This layer accepts projected patches and then adds positional
# information to them.

# %%
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches

# %% [markdown]
# ## Implement Locality Self Attention
#
# The regular attention equation is stated below.
#
# | ![Equation of attention](https://miro.medium.com/max/396/1*P9sV1xXM10t943bXy_G9yg.png) |
# | :--: |
# | [Source](https://towardsdatascience.com/attention-is-all-you-need-discovering-the-transformer-paper-73e5ff5e0634) |
#
# The attention module takes a query, key, and value. First, we compute the
# similarity between the query and key via a dot product. Then, the result
# is scaled by the square root of the key dimension. The scaling prevents
# the softmax function from having an overly small gradient. Softmax is then
# applied to the scaled dot product to produce the attention weights.
# The value is then modulated via the attention weights.
#
# In self-attention, query, key and value come from the same input.
# The dot product would result in large self-token relations rather than
# inter-token relations. This also means that the softmax gives higher
# probabilities to self-token relations than the inter-token relations.
# To combat this, the authors propose masking the diagonal of the dot product.
# This way, we force the attention module to pay more attention to the
# inter-token relations.
#
# The scaling factor is a constant in the regular attention module.
# This acts like a temperature term that can modulate the softmax function.
# The authors suggest a learnable temperature term instead of a constant.
#
# | ![Implementation of LSA](https://i.imgur.com/GTV99pk.png) |
# | :--: |
# | Locality Self Attention [Source](https://arxiv.org/abs/2112.13492v1) |
#
# The above two pointers make the Locality Self Attention. We have subclassed the
# [`layers.MultiHeadAttention`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MultiHeadAttention)
# and implemented the trainable temperature. The attention mask is built
# at a later stage.

# %%
class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# %% [markdown]
# ## Implement the MLP

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


# Build the diagonal attention mask
diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# %% [markdown]
# ## Build the ViT

# %%
def create_vit_classifier(vanilla=False):
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        if not vanilla:
            attention_output = MultiHeadAttentionLSA(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1, attention_mask=diag_attn_mask)
        else:
            attention_output = layers.MultiHeadAttention(
                num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
            )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# ## Compile, train, and evaluate the mode

# %%
# Some code is taken from:
# https://www.kaggle.com/ashusma/training-rfcx-tensorflow-tpu-effnet-b2.
class WarmUpCosine(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self, learning_rate_base, total_steps, warmup_learning_rate, warmup_steps
    ):
        super(WarmUpCosine, self).__init__()

        self.learning_rate_base = learning_rate_base
        self.total_steps = total_steps
        self.warmup_learning_rate = warmup_learning_rate
        self.warmup_steps = warmup_steps
        self.pi = tf.constant(np.pi)

    def __call__(self, step):
        if self.total_steps < self.warmup_steps:
            raise ValueError("Total_steps must be larger or equal to warmup_steps.")

        cos_annealed_lr = tf.cos(
            self.pi
            * (tf.cast(step, tf.float32) - self.warmup_steps)
            / float(self.total_steps - self.warmup_steps)
        )
        learning_rate = 0.5 * self.learning_rate_base * (1 + cos_annealed_lr)

        if self.warmup_steps > 0:
            if self.learning_rate_base < self.warmup_learning_rate:
                raise ValueError(
                    "Learning_rate_base must be larger or equal to "
                    "warmup_learning_rate."
                )
            slope = (
                self.learning_rate_base - self.warmup_learning_rate
            ) / self.warmup_steps
            warmup_rate = slope * tf.cast(step, tf.float32) + self.warmup_learning_rate
            learning_rate = tf.where(
                step < self.warmup_steps, warmup_rate, learning_rate
            )
        return tf.where(
            step > self.total_steps, 0.0, learning_rate, name="learning_rate"
        )


def run_experiment(model):
    total_steps = int((len(x_train) / BATCH_SIZE) * EPOCHS)
    warmup_epoch_percentage = 0.10
    warmup_steps = int(total_steps * warmup_epoch_percentage)
    scheduled_lrs = WarmUpCosine(
        learning_rate_base=LEARNING_RATE,
        total_steps=total_steps,
        warmup_learning_rate=0.0,
        warmup_steps=warmup_steps,
    )

    optimizer = tfa.optimizers.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_split=0.1,
    )
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


# Run experiments with the vanilla ViT
vit = create_vit_classifier(vanilla=True)
history = run_experiment(vit)

# Run experiments with the Shifted Patch Tokenization and
# Locality Self Attention modified ViT
vit_sl = create_vit_classifier(vanilla=False)
history = run_experiment(vit_sl)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 98s 490ms/step - loss: 2.0641 - accuracy: 0.3139 - top-5-accuracy: 0.8094 - val_loss: 1.5086 - val_accuracy: 0.4652 - val_top-5-accuracy: 0.9212
# Epoch 2/50
# 176/176 [==============================] - 86s 490ms/step - loss: 1.5439 - accuracy: 0.4430 - top-5-accuracy: 0.9027 - val_loss: 1.2600 - val_accuracy: 0.5544 - val_top-5-accuracy: 0.9470
# Epoch 3/50
# 176/176 [==============================] - 85s 484ms/step - loss: 1.3976 - accuracy: 0.5043 - top-5-accuracy: 0.9239 - val_loss: 1.1652 - val_accuracy: 0.5840 - val_top-5-accuracy: 0.9560
# Epoch 4/50
# 176/176 [==============================] - 86s 487ms/step - loss: 1.2922 - accuracy: 0.5428 - top-5-accuracy: 0.9379 - val_loss: 1.1178 - val_accuracy: 0.6214 - val_top-5-accuracy: 0.9580
# Epoch 5/50
# 176/176 [==============================] - 85s 483ms/step - loss: 1.2273 - accuracy: 0.5678 - top-5-accuracy: 0.9431 - val_loss: 1.0553 - val_accuracy: 0.6244 - val_top-5-accuracy: 0.9650
# Epoch 6/50
# 176/176 [==============================] - 86s 487ms/step - loss: 1.1745 - accuracy: 0.5870 - top-5-accuracy: 0.9512 - val_loss: 0.9837 - val_accuracy: 0.6502 - val_top-5-accuracy: 0.9706
# Epoch 7/50
# 176/176 [==============================] - 85s 483ms/step - loss: 1.1049 - accuracy: 0.6120 - top-5-accuracy: 0.9566 - val_loss: 0.9743 - val_accuracy: 0.6586 - val_top-5-accuracy: 0.9724
# Epoch 8/50
# 176/176 [==============================] - 85s 482ms/step - loss: 1.0710 - accuracy: 0.6257 - top-5-accuracy: 0.9603 - val_loss: 0.8813 - val_accuracy: 0.6952 - val_top-5-accuracy: 0.9806
# Epoch 9/50
# 176/176 [==============================] - 85s 485ms/step - loss: 1.0334 - accuracy: 0.6362 - top-5-accuracy: 0.9643 - val_loss: 0.8514 - val_accuracy: 0.7070 - val_top-5-accuracy: 0.9802
# Epoch 10/50
# 176/176 [==============================] - 85s 481ms/step - loss: 0.9875 - accuracy: 0.6549 - top-5-accuracy: 0.9662 - val_loss: 0.8200 - val_accuracy: 0.7198 - val_top-5-accuracy: 0.9820
# Epoch 11/50
# 176/176 [==============================] - 86s 487ms/step - loss: 0.9546 - accuracy: 0.6645 - top-5-accuracy: 0.9697 - val_loss: 0.8117 - val_accuracy: 0.7166 - val_top-5-accuracy: 0.9832
# Epoch 12/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.9176 - accuracy: 0.6779 - top-5-accuracy: 0.9721 - val_loss: 0.7788 - val_accuracy: 0.7358 - val_top-5-accuracy: 0.9804
# Epoch 13/50
# 176/176 [==============================] - 85s 485ms/step - loss: 0.8848 - accuracy: 0.6907 - top-5-accuracy: 0.9742 - val_loss: 0.7548 - val_accuracy: 0.7450 - val_top-5-accuracy: 0.9832
# Epoch 14/50
# 176/176 [==============================] - 85s 482ms/step - loss: 0.8571 - accuracy: 0.7016 - top-5-accuracy: 0.9752 - val_loss: 0.7356 - val_accuracy: 0.7524 - val_top-5-accuracy: 0.9868
# Epoch 15/50
# 176/176 [==============================] - 86s 486ms/step - loss: 0.8239 - accuracy: 0.7124 - top-5-accuracy: 0.9783 - val_loss: 0.7082 - val_accuracy: 0.7596 - val_top-5-accuracy: 0.9874
# Epoch 16/50
# 176/176 [==============================] - 85s 481ms/step - loss: 0.7989 - accuracy: 0.7181 - top-5-accuracy: 0.9795 - val_loss: 0.6873 - val_accuracy: 0.7596 - val_top-5-accuracy: 0.9878
# Epoch 17/50
# 176/176 [==============================] - 85s 485ms/step - loss: 0.7743 - accuracy: 0.7305 - top-5-accuracy: 0.9812 - val_loss: 0.6792 - val_accuracy: 0.7648 - val_top-5-accuracy: 0.9888
# Epoch 18/50
# 176/176 [==============================] - 84s 480ms/step - loss: 0.7571 - accuracy: 0.7365 - top-5-accuracy: 0.9822 - val_loss: 0.6675 - val_accuracy: 0.7612 - val_top-5-accuracy: 0.9868
# Epoch 19/50
# 176/176 [==============================] - 86s 486ms/step - loss: 0.7369 - accuracy: 0.7435 - top-5-accuracy: 0.9823 - val_loss: 0.6713 - val_accuracy: 0.7660 - val_top-5-accuracy: 0.9882
# Epoch 20/50
# 176/176 [==============================] - 85s 482ms/step - loss: 0.7229 - accuracy: 0.7442 - top-5-accuracy: 0.9835 - val_loss: 0.6360 - val_accuracy: 0.7766 - val_top-5-accuracy: 0.9886
# Epoch 21/50
# 176/176 [==============================] - 86s 486ms/step - loss: 0.6861 - accuracy: 0.7604 - top-5-accuracy: 0.9853 - val_loss: 0.6206 - val_accuracy: 0.7840 - val_top-5-accuracy: 0.9884
# Epoch 22/50
# 176/176 [==============================] - 85s 482ms/step - loss: 0.6794 - accuracy: 0.7632 - top-5-accuracy: 0.9859 - val_loss: 0.6191 - val_accuracy: 0.7802 - val_top-5-accuracy: 0.9902
# Epoch 23/50
# 176/176 [==============================] - 85s 486ms/step - loss: 0.6656 - accuracy: 0.7679 - top-5-accuracy: 0.9866 - val_loss: 0.6086 - val_accuracy: 0.7882 - val_top-5-accuracy: 0.9892
# Epoch 24/50
# 176/176 [==============================] - 84s 480ms/step - loss: 0.6444 - accuracy: 0.7736 - top-5-accuracy: 0.9881 - val_loss: 0.6237 - val_accuracy: 0.7824 - val_top-5-accuracy: 0.9888
# Epoch 25/50
# 176/176 [==============================] - 85s 485ms/step - loss: 0.6310 - accuracy: 0.7795 - top-5-accuracy: 0.9886 - val_loss: 0.6117 - val_accuracy: 0.7900 - val_top-5-accuracy: 0.9892
# Epoch 26/50
# 176/176 [==============================] - 85s 480ms/step - loss: 0.6162 - accuracy: 0.7832 - top-5-accuracy: 0.9886 - val_loss: 0.5920 - val_accuracy: 0.8006 - val_top-5-accuracy: 0.9884
# Epoch 27/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.5969 - accuracy: 0.7911 - top-5-accuracy: 0.9891 - val_loss: 0.5960 - val_accuracy: 0.7930 - val_top-5-accuracy: 0.9890
# Epoch 28/50
# 176/176 [==============================] - 85s 480ms/step - loss: 0.5819 - accuracy: 0.7963 - top-5-accuracy: 0.9903 - val_loss: 0.5728 - val_accuracy: 0.8030 - val_top-5-accuracy: 0.9896
# Epoch 29/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.5704 - accuracy: 0.7986 - top-5-accuracy: 0.9908 - val_loss: 0.5708 - val_accuracy: 0.7994 - val_top-5-accuracy: 0.9888
# Epoch 30/50
# 176/176 [==============================] - 85s 480ms/step - loss: 0.5565 - accuracy: 0.8049 - top-5-accuracy: 0.9916 - val_loss: 0.5769 - val_accuracy: 0.8002 - val_top-5-accuracy: 0.9890
# Epoch 31/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.5414 - accuracy: 0.8114 - top-5-accuracy: 0.9915 - val_loss: 0.5753 - val_accuracy: 0.7990 - val_top-5-accuracy: 0.9876
# Epoch 32/50
# 176/176 [==============================] - 85s 481ms/step - loss: 0.5290 - accuracy: 0.8154 - top-5-accuracy: 0.9923 - val_loss: 0.5579 - val_accuracy: 0.8072 - val_top-5-accuracy: 0.9894
# Epoch 33/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.5253 - accuracy: 0.8153 - top-5-accuracy: 0.9921 - val_loss: 0.5646 - val_accuracy: 0.8028 - val_top-5-accuracy: 0.9908
# Epoch 34/50
# 176/176 [==============================] - 84s 480ms/step - loss: 0.5036 - accuracy: 0.8219 - top-5-accuracy: 0.9926 - val_loss: 0.5720 - val_accuracy: 0.8008 - val_top-5-accuracy: 0.9890
# Epoch 35/50
# 176/176 [==============================] - 85s 482ms/step - loss: 0.5036 - accuracy: 0.8218 - top-5-accuracy: 0.9938 - val_loss: 0.5655 - val_accuracy: 0.8032 - val_top-5-accuracy: 0.9914
# Epoch 36/50
# 176/176 [==============================] - 84s 479ms/step - loss: 0.4895 - accuracy: 0.8285 - top-5-accuracy: 0.9939 - val_loss: 0.5401 - val_accuracy: 0.8114 - val_top-5-accuracy: 0.9920
# Epoch 37/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.4772 - accuracy: 0.8319 - top-5-accuracy: 0.9942 - val_loss: 0.5472 - val_accuracy: 0.8182 - val_top-5-accuracy: 0.9934
# Epoch 38/50
# 176/176 [==============================] - 84s 480ms/step - loss: 0.4664 - accuracy: 0.8369 - top-5-accuracy: 0.9944 - val_loss: 0.5534 - val_accuracy: 0.8180 - val_top-5-accuracy: 0.9902
# Epoch 39/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.4613 - accuracy: 0.8386 - top-5-accuracy: 0.9947 - val_loss: 0.5452 - val_accuracy: 0.8176 - val_top-5-accuracy: 0.9888
# Epoch 40/50
# 176/176 [==============================] - 85s 481ms/step - loss: 0.4453 - accuracy: 0.8418 - top-5-accuracy: 0.9955 - val_loss: 0.5418 - val_accuracy: 0.8152 - val_top-5-accuracy: 0.9906
# Epoch 41/50
# 176/176 [==============================] - 85s 485ms/step - loss: 0.4409 - accuracy: 0.8448 - top-5-accuracy: 0.9951 - val_loss: 0.5475 - val_accuracy: 0.8158 - val_top-5-accuracy: 0.9910
# Epoch 42/50
# 176/176 [==============================] - 84s 479ms/step - loss: 0.4318 - accuracy: 0.8482 - top-5-accuracy: 0.9952 - val_loss: 0.5356 - val_accuracy: 0.8220 - val_top-5-accuracy: 0.9902
# Epoch 43/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.4243 - accuracy: 0.8503 - top-5-accuracy: 0.9958 - val_loss: 0.5247 - val_accuracy: 0.8210 - val_top-5-accuracy: 0.9898
# Epoch 44/50
# 176/176 [==============================] - 84s 479ms/step - loss: 0.4175 - accuracy: 0.8530 - top-5-accuracy: 0.9957 - val_loss: 0.5537 - val_accuracy: 0.8148 - val_top-5-accuracy: 0.9900
# Epoch 45/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.4099 - accuracy: 0.8586 - top-5-accuracy: 0.9961 - val_loss: 0.5482 - val_accuracy: 0.8192 - val_top-5-accuracy: 0.9920
# Epoch 46/50
# 176/176 [==============================] - 84s 480ms/step - loss: 0.3953 - accuracy: 0.8582 - top-5-accuracy: 0.9969 - val_loss: 0.5236 - val_accuracy: 0.8256 - val_top-5-accuracy: 0.9902
# Epoch 47/50
# 176/176 [==============================] - 85s 484ms/step - loss: 0.3917 - accuracy: 0.8620 - top-5-accuracy: 0.9967 - val_loss: 0.5373 - val_accuracy: 0.8252 - val_top-5-accuracy: 0.9894
# Epoch 48/50
# 176/176 [==============================] - 85s 481ms/step - loss: 0.3857 - accuracy: 0.8632 - top-5-accuracy: 0.9968 - val_loss: 0.5356 - val_accuracy: 0.8226 - val_top-5-accuracy: 0.9932
# Epoch 49/50
# 176/176 [==============================] - 85s 481ms/step - loss: 0.3834 - accuracy: 0.8669 - top-5-accuracy: 0.9967 - val_loss: 0.5220 - val_accuracy: 0.8228 - val_top-5-accuracy: 0.9914
# Epoch 50/50
# 176/176 [==============================] - 85s 485ms/step - loss: 0.3624 - accuracy: 0.8725 - top-5-accuracy: 0.9966 - val_loss: 0.5683 - val_accuracy: 0.8256 - val_top-5-accuracy: 0.9924
# 40/40 [==============================] - 5s 119ms/step - loss: 0.6024 - accuracy: 0.8069 - top-5-accuracy: 0.9899
# Test accuracy: 80.69%
# Test top 5 accuracy: 98.99%
# Epoch 1/50
# 176/176 [==============================] - 103s 526ms/step - loss: 2.0078 - accuracy: 0.3286 - top-5-accuracy: 0.8149 - val_loss: 1.4928 - val_accuracy: 0.4784 - val_top-5-accuracy: 0.9186
# Epoch 2/50
# 176/176 [==============================] - 90s 514ms/step - loss: 1.5595 - accuracy: 0.4386 - top-5-accuracy: 0.8983 - val_loss: 1.3225 - val_accuracy: 0.5484 - val_top-5-accuracy: 0.9398
# Epoch 3/50
# 176/176 [==============================] - 91s 518ms/step - loss: 1.4072 - accuracy: 0.4955 - top-5-accuracy: 0.9225 - val_loss: 1.1472 - val_accuracy: 0.5964 - val_top-5-accuracy: 0.9548
# Epoch 4/50
# 176/176 [==============================] - 90s 514ms/step - loss: 1.2746 - accuracy: 0.5485 - top-5-accuracy: 0.9392 - val_loss: 1.0612 - val_accuracy: 0.6372 - val_top-5-accuracy: 0.9688
# Epoch 5/50
# 176/176 [==============================] - 92s 520ms/step - loss: 1.1736 - accuracy: 0.5855 - top-5-accuracy: 0.9512 - val_loss: 0.9804 - val_accuracy: 0.6532 - val_top-5-accuracy: 0.9688
# Epoch 6/50
# 176/176 [==============================] - 90s 513ms/step - loss: 1.0975 - accuracy: 0.6125 - top-5-accuracy: 0.9578 - val_loss: 0.9087 - val_accuracy: 0.6788 - val_top-5-accuracy: 0.9746
# Epoch 7/50
# 176/176 [==============================] - 91s 518ms/step - loss: 1.0360 - accuracy: 0.6366 - top-5-accuracy: 0.9627 - val_loss: 0.8807 - val_accuracy: 0.6924 - val_top-5-accuracy: 0.9754
# Epoch 8/50
# 176/176 [==============================] - 91s 515ms/step - loss: 0.9881 - accuracy: 0.6552 - top-5-accuracy: 0.9677 - val_loss: 0.7978 - val_accuracy: 0.7334 - val_top-5-accuracy: 0.9796
# Epoch 9/50
# 176/176 [==============================] - 91s 518ms/step - loss: 0.9453 - accuracy: 0.6668 - top-5-accuracy: 0.9696 - val_loss: 0.7862 - val_accuracy: 0.7332 - val_top-5-accuracy: 0.9806
# Epoch 10/50
# 176/176 [==============================] - 91s 515ms/step - loss: 0.9112 - accuracy: 0.6824 - top-5-accuracy: 0.9729 - val_loss: 0.7430 - val_accuracy: 0.7438 - val_top-5-accuracy: 0.9844
# Epoch 11/50
# 176/176 [==============================] - 91s 518ms/step - loss: 0.8789 - accuracy: 0.6932 - top-5-accuracy: 0.9748 - val_loss: 0.7332 - val_accuracy: 0.7514 - val_top-5-accuracy: 0.9806
# Epoch 12/50
# 176/176 [==============================] - 90s 514ms/step - loss: 0.8474 - accuracy: 0.7045 - top-5-accuracy: 0.9759 - val_loss: 0.7060 - val_accuracy: 0.7572 - val_top-5-accuracy: 0.9850
# Epoch 13/50
# 176/176 [==============================] - 91s 517ms/step - loss: 0.8200 - accuracy: 0.7136 - top-5-accuracy: 0.9783 - val_loss: 0.6922 - val_accuracy: 0.7638 - val_top-5-accuracy: 0.9842
# Epoch 14/50
# 176/176 [==============================] - 90s 512ms/step - loss: 0.7971 - accuracy: 0.7216 - top-5-accuracy: 0.9798 - val_loss: 0.6744 - val_accuracy: 0.7678 - val_top-5-accuracy: 0.9864
# Epoch 15/50
# 176/176 [==============================] - 91s 517ms/step - loss: 0.7730 - accuracy: 0.7341 - top-5-accuracy: 0.9809 - val_loss: 0.6560 - val_accuracy: 0.7770 - val_top-5-accuracy: 0.9864
# Epoch 16/50
# 176/176 [==============================] - 91s 515ms/step - loss: 0.7538 - accuracy: 0.7360 - top-5-accuracy: 0.9817 - val_loss: 0.6490 - val_accuracy: 0.7780 - val_top-5-accuracy: 0.9874
# Epoch 17/50
# 176/176 [==============================] - 91s 518ms/step - loss: 0.7256 - accuracy: 0.7474 - top-5-accuracy: 0.9826 - val_loss: 0.6245 - val_accuracy: 0.7832 - val_top-5-accuracy: 0.9868
# Epoch 18/50
# 176/176 [==============================] - 91s 515ms/step - loss: 0.7144 - accuracy: 0.7509 - top-5-accuracy: 0.9834 - val_loss: 0.6295 - val_accuracy: 0.7862 - val_top-5-accuracy: 0.9854
# Epoch 19/50
# 176/176 [==============================] - 91s 519ms/step - loss: 0.6931 - accuracy: 0.7588 - top-5-accuracy: 0.9844 - val_loss: 0.5974 - val_accuracy: 0.7948 - val_top-5-accuracy: 0.9886
# Epoch 20/50
# 176/176 [==============================] - 90s 513ms/step - loss: 0.6760 - accuracy: 0.7660 - top-5-accuracy: 0.9862 - val_loss: 0.5950 - val_accuracy: 0.7924 - val_top-5-accuracy: 0.9878
# Epoch 21/50
# 176/176 [==============================] - 91s 519ms/step - loss: 0.6625 - accuracy: 0.7674 - top-5-accuracy: 0.9864 - val_loss: 0.5854 - val_accuracy: 0.7972 - val_top-5-accuracy: 0.9888
# Epoch 22/50
# 176/176 [==============================] - 91s 515ms/step - loss: 0.6416 - accuracy: 0.7783 - top-5-accuracy: 0.9873 - val_loss: 0.5873 - val_accuracy: 0.8004 - val_top-5-accuracy: 0.9890
# Epoch 23/50
# 176/176 [==============================] - 91s 518ms/step - loss: 0.6211 - accuracy: 0.7845 - top-5-accuracy: 0.9883 - val_loss: 0.5758 - val_accuracy: 0.8036 - val_top-5-accuracy: 0.9912
# Epoch 24/50
# 176/176 [==============================] - 90s 514ms/step - loss: 0.6014 - accuracy: 0.7910 - top-5-accuracy: 0.9891 - val_loss: 0.5620 - val_accuracy: 0.8100 - val_top-5-accuracy: 0.9876
# Epoch 25/50
# 176/176 [==============================] - 91s 517ms/step - loss: 0.5933 - accuracy: 0.7930 - top-5-accuracy: 0.9898 - val_loss: 0.5541 - val_accuracy: 0.8104 - val_top-5-accuracy: 0.9894
# Epoch 26/50
# 176/176 [==============================] - 91s 515ms/step - loss: 0.5794 - accuracy: 0.7978 - top-5-accuracy: 0.9900 - val_loss: 0.5422 - val_accuracy: 0.8080 - val_top-5-accuracy: 0.9910
# Epoch 27/50
# 176/176 [==============================] - 91s 518ms/step - loss: 0.5656 - accuracy: 0.8022 - top-5-accuracy: 0.9901 - val_loss: 0.5622 - val_accuracy: 0.8030 - val_top-5-accuracy: 0.9900
# Epoch 28/50
# 176/176 [==============================] - 91s 517ms/step - loss: 0.5510 - accuracy: 0.8068 - top-5-accuracy: 0.9912 - val_loss: 0.5248 - val_accuracy: 0.8186 - val_top-5-accuracy: 0.9892
# Epoch 29/50
# 176/176 [==============================] - 91s 516ms/step - loss: 0.5309 - accuracy: 0.8143 - top-5-accuracy: 0.9917 - val_loss: 0.5407 - val_accuracy: 0.8160 - val_top-5-accuracy: 0.9874
# Epoch 30/50
# 176/176 [==============================] - 90s 514ms/step - loss: 0.5228 - accuracy: 0.8165 - top-5-accuracy: 0.9921 - val_loss: 0.5320 - val_accuracy: 0.8180 - val_top-5-accuracy: 0.9900
# Epoch 31/50
# 176/176 [==============================] - 92s 521ms/step - loss: 0.5101 - accuracy: 0.8213 - top-5-accuracy: 0.9926 - val_loss: 0.5638 - val_accuracy: 0.8136 - val_top-5-accuracy: 0.9874
# Epoch 32/50
# 176/176 [==============================] - 90s 514ms/step - loss: 0.5081 - accuracy: 0.8210 - top-5-accuracy: 0.9932 - val_loss: 0.5330 - val_accuracy: 0.8186 - val_top-5-accuracy: 0.9902
# Epoch 33/50
# 176/176 [==============================] - 92s 521ms/step - loss: 0.4869 - accuracy: 0.8296 - top-5-accuracy: 0.9936 - val_loss: 0.5291 - val_accuracy: 0.8192 - val_top-5-accuracy: 0.9906
# Epoch 34/50
# 176/176 [==============================] - 91s 516ms/step - loss: 0.4825 - accuracy: 0.8296 - top-5-accuracy: 0.9939 - val_loss: 0.5292 - val_accuracy: 0.8200 - val_top-5-accuracy: 0.9922
# Epoch 35/50
# 176/176 [==============================] - 91s 519ms/step - loss: 0.4731 - accuracy: 0.8357 - top-5-accuracy: 0.9931 - val_loss: 0.5533 - val_accuracy: 0.8102 - val_top-5-accuracy: 0.9900
# Epoch 36/50
# 176/176 [==============================] - 91s 514ms/step - loss: 0.4530 - accuracy: 0.8411 - top-5-accuracy: 0.9942 - val_loss: 0.5185 - val_accuracy: 0.8280 - val_top-5-accuracy: 0.9896
# Epoch 37/50
# 176/176 [==============================] - 91s 518ms/step - loss: 0.4435 - accuracy: 0.8445 - top-5-accuracy: 0.9947 - val_loss: 0.5249 - val_accuracy: 0.8198 - val_top-5-accuracy: 0.9892
# Epoch 38/50
# 176/176 [==============================] - 91s 515ms/step - loss: 0.4410 - accuracy: 0.8455 - top-5-accuracy: 0.9947 - val_loss: 0.5225 - val_accuracy: 0.8242 - val_top-5-accuracy: 0.9902
# Epoch 39/50
# 176/176 [==============================] - 91s 519ms/step - loss: 0.4387 - accuracy: 0.8468 - top-5-accuracy: 0.9955 - val_loss: 0.5307 - val_accuracy: 0.8238 - val_top-5-accuracy: 0.9900
# Epoch 40/50
# 176/176 [==============================] - 90s 513ms/step - loss: 0.4262 - accuracy: 0.8511 - top-5-accuracy: 0.9955 - val_loss: 0.5121 - val_accuracy: 0.8266 - val_top-5-accuracy: 0.9926
# Epoch 41/50
# 176/176 [==============================] - 91s 519ms/step - loss: 0.4111 - accuracy: 0.8568 - top-5-accuracy: 0.9960 - val_loss: 0.5299 - val_accuracy: 0.8292 - val_top-5-accuracy: 0.9896
# Epoch 42/50
# 176/176 [==============================] - 90s 514ms/step - loss: 0.4083 - accuracy: 0.8553 - top-5-accuracy: 0.9956 - val_loss: 0.5185 - val_accuracy: 0.8338 - val_top-5-accuracy: 0.9912
# Epoch 43/50
# 176/176 [==============================] - 91s 520ms/step - loss: 0.4010 - accuracy: 0.8584 - top-5-accuracy: 0.9959 - val_loss: 0.5127 - val_accuracy: 0.8308 - val_top-5-accuracy: 0.9930
# Epoch 44/50
#   5/176 [..............................] - ETA: 1:24 - loss: 0.3846 - accuracy: 0.8687 - top-5-accuracy: 0.9961

# %% [markdown]
# # Final Notes
#
# With the help of Shifted Patch Tokenization and Locality Self Attention,
# we were able to get ~**3-4%** top-1 accuracy gains on CIFAR100.
#
# The ideas on Shifted Patch Tokenization and Locality Self Attention
# are very intuitive and easy to implement. The authors also ablates of
# different shifting strategies for Shifted Patch Tokenization in the
# supplementary of the paper.
#
# I would like to thank [Jarvislabs.ai](https://jarvislabs.ai/) for
# generously helping with GPU credits.
#
# You can use the trained model hosted on [Hugging Face Hub](https://huggingface.co/keras-io/vit_small_ds_v2) and try the demo on [Hugging Face Spaces](https://huggingface.co/spaces/keras-io/vit-small-ds).

# %%
vit.save('./gdrive/MyDrive/GNR638/vit_model1_CIFAR10')
vit_sl.save('./gdrive/MyDrive/GNR638/vitsl_model1_CIFAR10')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e38f38d44bb2> in <module>
# ----> 1 vit.save('./gdrive/MyDrive/GNR638/vit_model1_CIFAR10')
#       2 vit_sl.save('./gdrive/MyDrive/GNR638/vitsl_model1_CIFAR10')
#
# NameError: name 'vit' is not defined

# %%
vit_load = tf.keras.models.load_model('./gdrive/MyDrive/GNR638/vitsl_model_CIFAR10')

# %%
n = y_test.shape[0]
x_pred = vit_load.predict(x_test[0:n])

# %%
pred = np.argmax(x_pred,axis=1)
actual = y_test[0:n].flatten()
accuracy = np.sum(pred==actual)*100/n
accuracy
