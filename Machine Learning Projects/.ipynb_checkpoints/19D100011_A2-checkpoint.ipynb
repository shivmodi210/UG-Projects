# %% [markdown]
# ## Assignment 2  ME 781  (Data Scale)
# 19D100011

# %% [markdown]
# ### Perform the following tasks in sequence:
#
# 1. Create a list of 5 open data sets available for machine learning along with their links for each of the three Data Types (Discrete data Type, Sequential (temporal) data Type and Spatial data Type)
#
#
# 2. Write a python code to input a dataset (csv file) of Discrete data type, automatically identify and print the
#
#     a. Number of attributes and number of entries
#
#     b. Data scale of each attribute
#
#     c. Data value of each attribute
#
#
# 3.      Write a python code to perform statistics on each data column based on its data scale.
#
#
# 4.      Can we use a box plot for visualizing ordinal data? (Yes/No). Explain why.
#
# ![MicrosoftTeams-image2.png](attachment:MicrosoftTeams-image2.png)
#
#
# 5.      Write a python code to visualize data in the csv file (a generalized method depending upon data scale)
#
#     Assignment instructions:
#     1. Naming convention: Please name your colab files as rollnumber_A2.ipynb.
#     2. Learn how to use markdown to add texts in colab to make your code interactive and understandable.
#     3. After completion of your assignment download the file as .ipynb and submit itusing Teams assignment tab.

# %% [markdown]
#   ###  We have a software to check plagiarism in code, if anyone found copying the code, strict action will be taken against such students and can also be given FR grade directly.
#
#   We  expect  you  to  upload  colab  notebooks  when  you  are  required  to  turn  your  programming assignments.  Please  make  sure  that  you  provide  enough  comments  in  the  code  for  the TAs to understand

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import mode
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 1. List of 5 open data sets

# %%
## Paste the URLs of open datasets here and add comments describing the dataset
url1 = "https://datasetsearch.research.google.com/search?query=%20Spatial%20Dataset&docid=L2cvMTFqbl84MV83dg%3D%3D"  #Spatial
url2 = "https://archive.ics.uci.edu/ml/datasets/Anticancer+peptides"   #Sequential
url3 = "https://archive.ics.uci.edu/ml/datasets/Cardiotocography" #Discrete
url4 = "https://archive.ics.uci.edu/ml/datasets/Airfoil+Self-Noise"  #Discrete
url5 = "https://archive.ics.uci.edu/ml/datasets/Algerian+Forest+Fires+Dataset++" #Discrete

# %% [markdown]
# ### 2.   Write a python code to input a dataset (csv file) of Discrete datatype, automatically identify and print the
#
#     a. Number of attributes and number of data points
#
#     b. Data scale of each attribute
#
#     c. Data value of each attribute

# %% [markdown]
# #### Note: The number of categories for categorical (nominal,ordinal) data scale for the evaluating datasets is not greater than 8.

# %%
def data_description(filename):
    ## Write a well commented function that inputs dataset file location (.csv file) and outputs the following
    ## 1. data_scale (of length = number of attributes)
    ## 2. data_value (of length = number of attributes)
    ## 3. imported dataset for later use
    ## It should also print those details for each attribute(Output must be similar to what is mentioned below)
    df = pd.read_csv(filename)  # Dataframe creation
    data_value = []
    data_scale = []
    
    for column in df:
        #Finding Data-Scale for each column
        if(len(df[column].unique()) > 7):       # If number of unique values are greater than 7 then Interval or Ratio
            if(min(df[column] < 0)):            # If minimum value of any column is negative than Interval else Ratio
                data_scale.append("interval")
            else:
                data_scale.append("ratio")
        elif(len(df[column].unique()) == 2 or len(df[column].unique()) == 3):
            data_scale.append("nominal")        # If only 2 and 3 uniques values present in column than Nominal else Ordinal
        else:
            data_scale.append("ordinal")
        
        # Finding Data-Value for each column
        if(df.dtypes[column] == "float64" ):    # If datatype of a column is float then Continuous else Discrete
             data_value.append("continuous")
        else:
             data_value.append("discrete")

    return data_scale, data_value, df
            
filename = "A2_example_dataset - students_demo.csv"

data_scale, data_value, df = data_description(filename)
print(f"This dataset contains {len(df)} entries, each with {len(df.columns)} attributes\n")
columns = df.columns
for i in range(len(data_scale)):
    print(f"{i} {columns[i]} : {data_scale[i]}, {data_value[i]}")
# Out:
# This dataset contains 649 entries, each with 6 attributes
#
# 0 gender : nominal, discrete
# 1 age : ratio, discrete
# 2 health_rating : ordinal, discrete
# 3 StudentIQ : ratio, discrete
# 4 no_of_courses : ratio, discrete
# 5 Marks : ratio, continuous

# %% [markdown]
#     Output must similar to this:
#
#     This dataset contains 649 entries, each with 6 attributes
#
#     0 gender : nominal, discrete
#     1 age : ratio, discrete
#     2 health_rating : ordinal, discrete
#     3 StudentIQ : ratio, discrete
#     4 no_of_courses : ratio, discrete
#     5 Marks : ratio, continuous

# %% [markdown]
# ### 3. Write a python code to perform statistics on each data column based on its data scale.

# %%
def stats(filename):
    ## Write a well commented function that calls the function data_description and prints
    ## relevant statistics based on data scale.
    ## Hint: Explore describe()
    data_scale, data_value, df = data_description(filename)     # Reading data scales, data values and dataframe from filename
    entries = df[df.columns[0]].count()
    attributes = list(df.columns)
    
    for i in range(len(attributes)):            # Generating statistical data depending scale of data
        print(attributes[i])
        
        if data_scale[i] == 'ratio':            
            mode = float(df[attributes[i]].mode()[0])          # Calculating Mode for Ratio scale
            print("mode      {}".format(mode))
            print(df[attributes[i]].describe(include = 'all'), "\n")   # Printing count, mean, standard deviation, min, medians and max parameters 

        else:
            mode = df[attributes[i]].mode()[0]                # Calculating mode for other scale
            print("mode {}".format(mode))
            if data_scale[i] == 'ordinal':
                median = df[attributes[i]].median()           # If data scale is ordinal, calculating median
                print("median {}".format(median))

            for val in df[attributes[i]].unique():
                col_list = list(df[attributes[i]])
                print("{}      {}".format(val, col_list.count(val)))
            print("Name: {}, dtype: {} \n".format(attributes[i], df[attributes[i]].dtype))
      
    return
stats('A2_example_dataset - students_demo.csv')
# Out:
# gender
# mode F
# F      383
# M      266
# Name: gender, dtype: object
#
# age
# mode      17.0
# count    649.000000
# mean      16.744222
# std        1.218138
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64
#
# health_rating
# mode 5
# median 4.0
# 3      124
# 5      249
# 1      90
# 2      78
# 4      108
# Name: health_rating, dtype: int64
#
# StudentIQ
# mode      104.0
# count    649.000000
# mean     100.229584
# std       10.256494
# min       75.000000
# 25%       93.000000
# 50%      101.000000
# 75%      107.000000
# max      131.000000
# Name: StudentIQ, dtype: float64
#
# no_of_courses
# mode      17.0
# count    649.000000
# mean      10.596302
# std        5.714697
# min        1.000000
# 25%        5.000000
# 50%       11.000000
# 75%       16.000000
# max       20.000000
# Name: no_of_courses, dtype: float64
#
# Marks
# mode      52.81
# count    649.000000
# mean      75.137257
# std       14.559722
# min       50.120000
# 25%       62.560000
# 50%       75.120000
# 75%       87.670000
# max       99.860000
# Name: Marks, dtype: float64

# %% [markdown]
#     Output must be some what similar to this:
#
#     gender
#     mode F
#     F    383
#     M    266
#     Name: gender, dtype: int64
#
#     age
#     mode      17.000000
#     mean      16.744222
#     std        1.218138
#     min       15.000000
#     25%       16.000000
#     median    17.000000
#     75%       18.000000
#     max       22.000000
#     Name: age, dtype: float64
#
#     health_rating
#     mode   5
#     median 4
#     1     90
#     2     78
#     3    124
#     4    108
#     5    249
#     Name: health_rating, dtype: int64
#
#     StudentIQ
#     mode     104.000000
#     mean     100.229584
#     std       10.256494
#     min       75.000000
#     25%       93.000000
#     median   101.000000
#     75%      107.000000
#     max      131.000000
#     Name: StudentIQ, dtype: float64
#
#     no_of_courses
#     mode      17.000000
#     count    649.000000
#     mean      10.596302
#     std        5.714697
#     min        1.000000
#     25%        5.000000
#     median    11.000000
#     75%       16.000000
#     max       20.000000
#     Name: no_of_courses, dtype: float64
#
#     Marks
#     mode      52.810000
#     count    649.000000
#     mean      75.137257
#     std       14.559722
#     min       50.120000
#     25%       62.560000
#     median    75.120000
#     75%       87.670000
#     max       99.860000
#     Name: Marks, dtype: float64

# %% [markdown]
# ### 4. Can we use a box plot for visualizing ordinal data ? (Yes/No). Explain why.
# ![MicrosoftTeams-image2.png](attachment:MicrosoftTeams-image2.png)

# %% [markdown]
# ### Write your answer here.
#     YES, Because it provides some statistical parameters like counts, mean, max, min, standard deviation, counts, medians. Also, its easy to interpret and very informative in single plot.

# %% [markdown]
# ###   5.  Write a python code to visualize the data (a generalized method depending on data scale)

# %%
def visualize_data(filename):
        ## Write a well commented function that can call any of the functions from above 
        ## to plot relevant plots
        ## Hint: Use sns.distplot, sns.countplot. Make a new figure for each plot (plt.figure(i))
    df = pd.read_csv(filename)
    
    for i in range(len(columns)):
        x = df[columns[i]]                  # Now we decide type of plot depending the number of unique values in columns
        if(len(x.unique()) > 7):
            plt.figure(i)
            ax = sns.distplot(x)
            ax.plot()
            plt.show()
        elif(len(x.unique()) == 2 or len(x.unique()) == 3):
            plt.figure(i)
            ax = sns.countplot(x)
            plt.tight_layout()
            ax.plot()
            plt.show()
        else:
            plt.figure(i)
            y = df['Marks']
            ax = sns.boxplot(x = x, y = y)
            plt.show()
            
name = "A2_example_dataset - students_demo.csv"
visualize_data(name)
