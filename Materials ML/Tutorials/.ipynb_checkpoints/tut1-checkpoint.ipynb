# %% [markdown]
# <h1><center>Tutorial 1</center></h1>
# <h2><center>Prepared by Alankar</center></h2>
# <h2><center>Section 1 - Introduction to Python language, popular libraries, linear algebra etc.</center></h2>

# %%
print('fit a model with', 11, 'variables')
# Out:
# fit a model with 11 variables

# %% [markdown]
# Information about a function can be printed by adding a '?' mark in front of the command.

# %%
print?

# %%
b=2
c=3
a=b+c
a
# Out:
# 5

# %%
print(a)
# Out:
# 5

# %%
print('The sum of b and c is '+str(a)+'.')
# Out:
# The sum of b and c is 5.

# %%
'hello' + ' world'
# Out:
# 'hello world'

# %% [markdown]
# Try another method of creating a space.

# %%
string = "hello"+" "+"world"
print(string)
# Out:
# hello world

# %% [markdown]
# Join three numbers and create a list

# %%
x=[3,5,7]

# %%
x
# Out:
# [3, 5, 7]

# %% [markdown]
# Create another list

# %%
y=[5,7,9,2]

# %%
x+y # this will concatenate the lists
# Out:
# [3, 5, 7, 5, 7, 9, 2]

# %%
names = ['a','b','c','d']
names
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ### Data science capabilities of Python are primarily from Pandas and Numpy libraries. Numpy is an abbreviated form of Numerical Python. A library or a package is a collection of several modules that are not part of the base Python package.

# %%
import numpy as np

# %% [markdown]
# Let us create arrays. In Numpy, an array is a generic multidimensional set of numbers.

# %%
x = np.array([3, 4, 5])
y = np.array([4, 9, 7])

# %%
x+y
# Out:
# array([ 7, 13, 12])

# %%
x.ndim # check the dimenions of array x.
# Out:
# 1

# %%
x = np.array([[1, 2], [3, 4]])
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
x.dtype # data type of x
# Out:
# dtype('int64')

# %%
x = np.array([[1, 2], [3, 4]])

# %%
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
x.ndim
# Out:
# 2

# %%
np.array([[1, 2], [3.0, 4]]).dtype
# Out:
# dtype('float64')

# %% [markdown]
# One can convert an integer type array into a float type array by passing an argument

# %%
x = np.array([[1, 2], [3, 4]],float)

# %%
x
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
x.dtype
# Out:
# dtype('float64')

# %%
x.shape
# Out:
# (2, 2)

# %%
x.sum() # It will add all the elements of the array, irrespective of the shape of the array.
# Out:
# 10.0

# %% [markdown]
# Another method of summing an array is by passing the numpy array as an argument to np.sum()

# %%
np.sum(x)
# Out:
# 21

# %%
x=np.array([1,2,3,4,5,6])
print('Original x:\n', x)
x_reshape = x.reshape((2, 3))
print('Reshaped x:\n', x_reshape)
# Out:
# Original x:
#  [1 2 3 4 5 6]
# Reshaped x:
#  [[1 2 3]
#  [4 5 6]]

# %%
x_reshape[0, 0]
# Out:
# 1

# %%
x_reshape[0, 2]
# Out:
# 3

# %%
print('x before we modify x_reshape: \n',x)
print('x_reshape before we modify x_reshape:\n', x_reshape)
x_reshape[0, 0] = 5
print('x_reshape after we modify its top left element:\n',x_reshape)
print('x after we modify top left element of x_reshape:\n', x)
# Out:
# x before we modify x_reshape:
#  [1 2 3 4 5 6]
# x_reshape before we modify x_reshape:
#  [[1 2 3]
#  [4 5 6]]
# x_reshape after we modify its top left element:
#  [[5 2 3]
#  [4 5 6]]
# x after we modify top left element of x_reshape:
#  [5 2 3 4 5 6]

# %% [markdown]
# ### Generating a random matrix of size 10 x 10

# %%
A=np.random.randint(10, size=(10, 10))

# %%
Ainv=np.linalg.inv(A) # Determine inverse of A
Ainv
# Out:
# array([[-1.53270668e-01, -1.27340941e-01,  2.88005338e-01,
#         -1.22599702e-01, -3.37725533e-02,  1.94607110e-02,
#          1.11248509e-01,  8.38671100e-02, -2.19093885e-01,
#          2.95879411e-01],
#        [-6.17944142e-02, -1.83421324e-01,  2.68781417e-01,
#          5.90851543e-03, -4.01321682e-02,  5.59058820e-02,
#          4.56531446e-02,  1.17704159e-02, -2.02797311e-01,
#          2.45199570e-01],
#        [ 8.32518917e-02,  1.17913504e-01, -3.01013337e-01,
#          6.87955832e-02,  1.72710470e-02, -2.65264982e-02,
#         -6.76683430e-02,  3.44540173e-02,  1.73771975e-01,
#         -1.67245380e-01],
#        [-6.48346191e-03, -8.88441694e-02, -6.99981227e-03,
#         -8.68471983e-03,  6.31344565e-02, -5.03360209e-02,
#          5.54794027e-02,  9.13240438e-02, -1.01363907e-01,
#          1.16819374e-01],
#        [ 4.88728493e-02,  2.10650966e-01, -4.77937782e-01,
#          1.41856101e-01,  5.07376124e-02,  1.36715883e-05,
#         -7.48621608e-03, -3.77302593e-02,  2.37625457e-01,
#         -3.25631898e-01],
#        [ 1.37190878e-01,  1.33318690e-01, -3.97984593e-02,
#         -1.58779301e-03, -5.08647428e-02,  2.08269034e-02,
#         -2.85086582e-02, -1.74633568e-01,  5.02556189e-02,
#         -1.16039565e-01],
#        [ 6.97319312e-03, -3.11991909e-02,  1.00016029e-01,
#          1.52132920e-02, -5.56309172e-02, -5.82689419e-02,
#         -1.29834128e-03, -8.55426524e-05,  8.67770618e-02,
#         -2.84961985e-02],
#        [ 2.96755312e-03,  4.95082429e-03,  1.47511750e-01,
#         -1.37144698e-02, -9.00070131e-02,  2.57122407e-02,
#          2.82828424e-03,  4.41516341e-02, -2.10379017e-02,
#         -8.68191185e-02],
#        [-5.74778817e-02, -6.71874261e-02,  2.25124982e-01,
#         -3.13279707e-02,  2.38834462e-02, -5.24360499e-02,
#         -4.76487023e-02,  3.24149612e-02, -1.27807211e-01,
#          2.14365750e-01],
#        [-5.38527419e-03,  2.68524159e-02, -1.05396311e-01,
#         -4.95500604e-02,  1.45859786e-01,  6.66099297e-02,
#         -2.16915188e-02, -9.54576200e-02,  7.53353306e-02,
#         -8.85855960e-03]])

# %%
A=[[1,2,3],
   [4,3,7],
   [7,2,6]]
#Ainvertible=[[1,0,0],
#   [-1,1,0],
#   [0,-1,1]]

# %%
Ainv=np.linalg.inv(A)
Ainv
# Out:
# array([[ 0.26666667, -0.4       ,  0.33333333],
#        [ 1.66666667, -1.        ,  0.33333333],
#        [-0.86666667,  0.8       , -0.33333333]])

# %%
print(type(A))
# Out:
# <class 'list'>

# %%
print(type(x))
# Out:
# <class 'numpy.ndarray'>

# %%
A=np.array([[1,2,3],
   [4,3,7],
   [7,2,6]])

# %%
print(type(A))
# Out:
# <class 'numpy.ndarray'>

# %%
c=2

# %%
A+c # Broadcasting. This will add 2 to all the elements.
# Out:
# array([[3, 4, 5],
#        [6, 5, 9],
#        [9, 4, 8]])

# %%
B=np.array([[4,6,1],
   [9,5,2],
   [11,3,4]])

# %%
sum = A[:,:]+B[:,:]
print(sum)
# Out:
# [[ 5  8  4]
#  [13  8  9]
#  [18  5 10]]

# %%
print("A[0]",A[0]) # prints the first row. In Python array indices start from 0 by default.
# Out:
# A[0] [1 2 3]

# %%
print("A[0,1]",A[0,1]) # prints an element
# Out:
# A[0,1] 2

# %%
np.transpose(A)
# Out:
# array([[1, 4, 7],
#        [2, 3, 2],
#        [3, 7, 6]])

# %%
A=np.array([[4,2,3,6,7],
   [4,3,7,7,12],
   [3,12,8,8,4],
   [7,52,9,5,6],
   [9,6,2,1,6]])

# %%
columns = ('Apple', 'Mango', 'Papaya', 'Banana', 'Pear')
rows = ('U','V','W','X','Y')

# %%
A+b
# Out:
# array([[ 6,  4,  5,  8,  9],
#        [ 6,  5,  9,  9, 14],
#        [ 5, 14, 10, 10,  6],
#        [ 9, 54, 11,  7,  8],
#        [11,  8,  4,  3,  8]])

# %% [markdown]
# If you would like to know more about a function in Jupyter notebook, there are two methods:
# 1. type help(function_name) in a cell and execute.
# 2. place the curser inside the '(' ')' and press Shift + Tab

# %% [markdown]
# ### Decompose a matrix M into its eigenvectors and eigenvalues

# %%
w,v = np.linalg.eig(A)
print(w) # each element of this vector is an eigenvalue
print(v) # each column of this matrix V is eigenvector
# Out:
# [ 36.6092993 +0.j         -16.29326513+0.j
#    5.90333239+0.j          -0.10968328+4.15840585j
#   -0.10968328-4.15840585j]
# [[-0.24456528+0.j         -0.26829297+0.j         -0.15985314+0.j
#   -0.00712183-0.31662282j -0.00712183+0.31662282j]
#  [-0.34718312+0.j         -0.32305351+0.j         -0.05111532+0.j
#    0.02385405+0.12975252j  0.02385405-0.12975252j]
#  [-0.41644447+0.j         -0.12561544+0.j          0.80012935+0.j
#   -0.35491287-0.41613924j -0.35491287+0.41613924j]
#  [-0.78045088+0.j          0.88318549+0.j          0.19740656+0.j
#    0.65484328+0.j          0.65484328-0.j        ]
#  [-0.19267106+0.j          0.16691154+0.j         -0.54097863+0.j
#   -0.22373065+0.32293096j -0.22373065-0.32293096j]]

# %% [markdown]
# ### Now let us do some simple verification of eigenvalues and eigenvectors

# %%
v1=v[:,0] # extract the first eigen vector
print(v1)
# Out:
# [-0.24456528+0.j -0.34718312+0.j -0.41644447+0.j -0.78045088+0.j
#  -0.19267106+0.j]

# %%
print(w[0]*v1) # multiply the first eigenvector with the first eigenvalue
# Out:
# [ -8.95336342+0.j -12.71013058+0.j -15.24574024+0.j -28.57175989+0.j
#   -7.05355234+0.j]

# %%
print(np.matmul(A,v1)) # multiply the matrix A with its first eigenvector
# Out:
# [ -8.95336342+0.j -12.71013058+0.j -15.24574024+0.j -28.57175989+0.j
#   -7.05355234+0.j]

# %% [markdown]
# ### The above two rows show that $Av = \lambda v$ where $v$ is one of the eigenvectors and $\lambda$ is the corresponding eigenvalue of A.

# %%
print(np.linalg.det(A)) # This is the determinant using det() function
print(w[0]*w[1]*w[2]) # This is the determinant using multiplication of eigenvalues.
# Out:
# -60932.99999999995
# (-3521.2493393940586+0j)

# %% [markdown]
# ### det(A) = $\lambda_1 \times \lambda_2 \times \lambda_3$. The above results is correct within machine precision.

# %% [markdown]
# ### Matrix multiplication

# %%
A=np.array([[1,2,3],
   [4,3,7],
   [7,2,6]])
B=np.array([[4,6,1],
   [9,5,2],
   [11,3,4]])
C=np.array([[ 6,10,7],
 [17,11,16],
 [25,7,16]])
D=np.matmul(A,np.matmul(B,C)) # D = ABC
print(D)
print(np.trace(D)) # And then determine trace of D
# Out:
# [[1180  944 1057]
#  [2690 2126 2408]
#  [2737 2135 2464]]
# 5770

# %%
E=np.matmul(C,np.matmul(A,B)) # E = CAB
print(E)
print(np.trace(E)) # determine trace of E
# Out:
# [[2314 1240  727]
#  [4047 2205 1267]
#  [4007 2165 1251]]
# 5770

# %%
F=np.matmul(B,np.matmul(C,A)) # F = BCA
print(F)
print(np.trace(F)) # trace of F
# Out:
# [[1583  921 2084]
#  [2050 1205 2730]
#  [2224 1325 2982]]
# 5770

# %% [markdown]
# ### The above shows that trace(ABC) = trace(CAB) = trace(BCA)

# %% [markdown]
# <h2><center>Section 2 - Plotting</center></h2>

# %% [markdown]
# ### Creating points drawn from normal distribution

# %%
import matplotlib.pyplot as plt
#import seaborn as sns
#import subplots
#sns.set()
fig, ax = plt.subplots(figsize=(8, 8))
x = np.random.standard_normal(100)
y = np.random.standard_normal(100)
ax.scatter(x, y);
x = np.random.standard_normal(100)-5
y = np.random.standard_normal(100)-5
ax.scatter(x, y);
x = np.random.standard_normal(100)-5
y = np.random.standard_normal(100)+5
ax.scatter(x, y);

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.plot(x, y, 'o'); # Instead of scatter, one can also use 'o' which tell the function to use a symbol.

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
ax.set_title("Plot of X vs Y")
ax.scatter(x,y);

# %%
fig.set_size_inches(12,3)
fig

# %%
fig, axes = plt.subplots(nrows=2, ncols=3,figsize=(15, 5))

# %%
axes[0,1].plot(x, y, 'o') # This adds a scatter plot in the second plot of the first row.
axes[1,2].scatter(x, y, marker='+') # This adds a scatter plot in the third plot of the second row.
fig

# %%
fig.savefig("Figure.png", dpi=400)
fig.savefig("Figure.pdf", dpi=200);

# %%
axes[0,1].set_xlim([-1,1])
fig.savefig("Figure_updated.jpg")
fig

# %% [markdown]
# ### Plotting contours

# %%
fig, ax = plt.subplots(figsize=(8, 8))
x = np.linspace(-np.pi, np.pi, 50)
y=x
f = np.multiply.outer(np.cos(y), 1 / (1 + x**2))
ax.contour(x, y, f);

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.contour(x, y, f, levels=45);

# %%
fig, ax = plt.subplots(figsize=(8, 8))
plt.grid(visible=None)
ax.imshow(f);

# %% [markdown]
# # Plotting a vector

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a single vector
U = np.array([1,0])
V = np.array([1,1])
W = np.array([2,1])

# Create the plot
fig, ax = plt.subplots()

# Add the vector V to the plot
ax.quiver(0, 0, U[0], U[1], angles='xy', scale_units='xy', scale=1, color='r')
ax.quiver(1, 0, V[0], V[1], angles='xy', scale_units='xy', scale=1, color='g')
ax.quiver(0, 0, W[0], W[1], angles='xy', scale_units='xy', scale=1, color='b')

# Set the x-limits and y-limits of the plot
ax.set_xlim([-1, 2])
ax.set_ylim([-1, 2])

# Show the plot along with the grid
plt.grid(visible='yes')
plt.show()

# %% [markdown]
# ### In Matplotlib 'ax' is an instance of the axes that contain important information about each plot, such as its x- and y-axis labels, title, and more. Note that in matplotlib, the word axes is not the plural of axis: a plot’s axes contains much more information than just the x-axis and the y-axis. To know more about it, type "ax.plot?" in the next command line and execute.

# %% [markdown]
# # Reading data from a file

# %%
import pandas as pd
Auto = pd.read_csv('Auto.csv')
Auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 392       1            ford mustang gl
# 393       2                  vw pickup
# 394       1              dodge rampage
# 395       1                ford ranger
# 396       1                 chevy s-10
#
# [397 rows x 9 columns]

# %%
Auto['cylinders']
# Out:
# 0      8
# 1      8
# 2      8
# 3      8
# 4      8
#       ..
# 392    4
# 393    4
# 394    4
# 395    4
# 396    4
# Name: cylinders, Length: 397, dtype: int64
