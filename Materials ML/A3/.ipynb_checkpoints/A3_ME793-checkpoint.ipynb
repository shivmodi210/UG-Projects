# %% [markdown]
# # Assignment 3 ME 793
# ## Roll No.: 19D100011

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Loading the data
data = pd.read_csv("material_data.csv")
data.head()
# Out:
#   Elements  Atomic_Number  Electronegativity  Atomic_Radius  \
# 0        H              1               2.20           0.25
# 1       He              2               0.00           1.20
# 2       Li              3               0.98           1.45
# 3       Be              4               1.57           1.05
# 4        B              5               2.04           0.85
#
#    Thermal_Conductivity  Density Crystal_System
# 0                0.1805     0.09            HEX
# 1                0.1513     0.18            HCP
# 2               85.0000   530.00            BCC
# 3              190.0000  1850.00            HCP
# 4               27.0000  2340.00            RHO

# %% [markdown]
# # Plotting electronegativity vs. atomic number.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['Atomic_Number'], data['Electronegativity'], color='blue')
plt.title('Scattered Plot')
plt.xlabel('Atomic Number')
plt.ylabel('Electronegativity')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Atomic_Number'], data['Electronegativity'], marker='o', color='blue')
plt.title('Line Plot')
plt.xlabel('Atomic Number')
plt.ylabel('Electronegativity')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Number of Peaks: 6
# Based on Electronegativity vs. Atomic Number graph there are 6 peaks

# %% [markdown]
# # Performing K Means clustering

# %%
# Select relevant features for clustering
features = data[['Electronegativity', 'Atomic_Number']]
k = 6

# Color map
colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'purple']

# Perform KMeans clustering
kmeans = KMeans(n_clusters=k, random_state=42)
data['Cluster'] = kmeans.fit_predict(features) + 1

# Plot clusters
plt.figure(figsize=(10, 6))

# Plot each cluster
for cluster_num, color in zip(range(1, k+1), colors):
    cluster_data = data[data['Cluster'] == cluster_num]
    plt.scatter(cluster_data['Atomic_Number'], cluster_data['Electronegativity'], color=color, label=f'Cluster {cluster_num}')

# Plot centroids
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 1], centroids[:, 0], marker='*', s=200, c='black', label='Centroids')

# Labels and legend
plt.xlabel('Atomic Number')
plt.ylabel('Electronegativity')
plt.title('Clustering of Elements based on Peaks')
plt.legend()
plt.grid(True)
plt.show()

# %%
data.to_csv('data.csv', index=False)

# %% [markdown]
# # Elbow Method
# Finding best k using the Elbow method using Distortion

# %%
distortions = []
K = range(2, 15)
for k in K:
    k_means = KMeans(n_clusters=k, random_state=42)
    k_means.fit(features)
    distortions.append(sum(np.min(cdist(features, k_means.cluster_centers_,'euclidean'), axis=1)) / features.shape[0])

# %%
plt.plot(K, distortions, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Distortion')
plt.title('The Elbow Method using Distortion')
plt.show()

# %% [markdown]
# This plot doesn't have pointy elbow but we can see k=5 and k=6 are relatively appropriate values

# %% [markdown]
# # Let's plot for k=5 and k=7

# %%
# Perform KMeans clustering
k = 5
kmeans = KMeans(n_clusters=k, random_state=42)
data['Cluster'] = kmeans.fit_predict(features) + 1

# Plot clusters
plt.figure(figsize=(10, 6))

# Plot each cluster
for cluster_num, color in zip(range(1, k+1), colors):
    cluster_data = data[data['Cluster'] == cluster_num]
    plt.scatter(cluster_data['Atomic_Number'], cluster_data['Electronegativity'], color=color, label=f'Cluster {cluster_num}')

# Plot centroids
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 1], centroids[:, 0], marker='*', s=200, c='black', label='Centroids')

# Labels and legend
plt.xlabel('Atomic Number')
plt.ylabel('Electronegativity')
plt.title('Clustering of Elements based on Peaks (k=5)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Perform KMeans clustering
k = 7
kmeans = KMeans(n_clusters=k, random_state=42)
data['Cluster'] = kmeans.fit_predict(features) + 1

# Plot clusters
plt.figure(figsize=(10, 6))

# Plot each cluster
for cluster_num, color in zip(range(1, k+1), colors):
    cluster_data = data[data['Cluster'] == cluster_num]
    plt.scatter(cluster_data['Atomic_Number'], cluster_data['Electronegativity'], color=color, label=f'Cluster {cluster_num}')

# Plot centroids
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:, 1], centroids[:, 0], marker='*', s=200, c='black', label='Centroids')

# Labels and legend
plt.xlabel('Atomic Number')
plt.ylabel('Electronegativity')
plt.title('Clustering of Elements based on Peaks (k=7)')
plt.legend()
plt.grid(True)
plt.show()
