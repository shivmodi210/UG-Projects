# %%
import matplotlib.pyplot as plt
from sklearn import datasets  
import pandas as pd
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('final_data.csv')
corrdata = data.iloc[:, 0:14]

matrix = corrdata.corr()

# %%
plt.imshow(matrix, cmap='seismic')
 
plt.colorbar()

# %%
pca = PCA()
components = pca.fit_transform(corrdata)

# %%
print(components)
# Out:
# [[-5.89715952e+02 -1.24943662e+02 -2.29199395e-01 ...  1.35501319e-01
#    5.83049347e-02  9.95635328e-03]
#  [-8.56629504e+02  8.64367585e+01  1.10607992e+01 ...  3.15969762e-02
#    3.48661265e-02  8.42852456e-03]
#  [-9.99621402e+02  2.54857219e+02  2.88746639e+01 ... -6.61426312e-02
#    1.47734031e-02  3.34923019e-02]
#  ...
#  [ 1.95779158e+01  2.29648193e+01 -1.29523167e+01 ...  3.60429317e-02
#    5.27179412e-03  9.57815619e-03]
#  [ 1.64315155e+02  1.36779368e+02 -1.13134996e+01 ...  8.64363839e-02
#   -6.36417968e-03  3.20099704e-02]
#  [ 1.75111055e+02 -1.24767837e+02  3.22009098e+01 ...  3.95947356e-02
#    2.43447034e-02 -5.26541770e-03]]
